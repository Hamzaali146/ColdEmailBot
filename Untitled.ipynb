# %%
from langchain_groq import ChatGroq
llm = ChatGroq(
    temperature = 0,
    groq_api_key="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",
    model_name = "llama-3.1-70b-versatile"
)

# %%
print(llm.invoke("""
\documentclass[a4paper,10pt]{article}
\usepackage{geometry}
\usepackage{fontawesome5} % For icons
\usepackage{xcolor}
\usepackage{enumitem}
\usepackage{titlesec}
\usepackage{parskip}
\usepackage{hyperref}

% Page setup
\geometry{top=1.5cm, bottom=2cm, left=2.5cm, right=2.5cm}
\setlength{\parskip}{0.2em}

% Define Colors
\definecolor{primary}{HTML}{2C3E50}
\definecolor{accent}{HTML}{1D89FF}
\definecolor{lightgray}{HTML}{F4F6F8}

% Define header and footer formatting
\pagestyle{empty}

% Section header format
\titleformat{\section}{\color{primary}\scshape\large}{}{0pt}{}[\vspace{0.5em}\titlerule]

% Custom itemize symbol
\renewcommand{\labelitemi}{\faCircle}

% Hyperlink color
\hypersetup{
    colorlinks=true,
    urlcolor=accent
}

% Start document
\begin{document}

% ------------------- Header -------------------
\begin{minipage}[t]{0.7\textwidth}
    \vspace{-0.5cm}
    \LARGE \textbf{Dora Ware} \\
    \large Project Manager - Remote \\
\end{minipage}
\begin{minipage}[t]{0.3\textwidth}
    \vspace{-0.5cm}
    \raggedleft
    \faEnvelope\hspace{0.5em} \href{mailto:dora@novoresume.com}{dora@novoresume.com} \\
    \faPhone\hspace{0.5em} 123 444 555 \\
    \faMapMarkerAlt\hspace{0.5em} Miami, Working Remotely \\
    \faLinkedin\hspace{0.5em} \href{https://linkedin.com/in/dora.ware}{linkedin.com/in/dora.ware} \\
\end{minipage}

\vspace{1em}

% ------------------- Profile Summary -------------------
\noindent
\textbf{Dynamic and goal-driven Project Manager} with \textbf{10+ years of comprehensive background} in providing client-centric solutions across diverse sectors. Equipped with a record of success in project management, combined with demonstrated abilities in project coordination, programming, invoicing, scheduling, cost analysis, site measurements, quality calculations, and quality assurance. Looking for an opportunity to apply my project management, remote skills, and grow professionally.

\vspace{1.5em}

% ------------------- Work Experience -------------------
\section*{Work Experience}

% Job 1
\noindent
\textbf{Project Manager} \hfill \textit{GHG Logistics} \\
\textit{02/2018 -- Present} \hfill \textit{Miami, Working Remotely} \\
\begin{itemize}[left=0pt, itemsep=0.2em]
    \item Oversee responsibility for the management of multiple technical initiatives, while maintaining general quality assurance and optimum process flow, improving company growth.
    \item Develop implementation strategies and increase the company's productivity rate by 10\%.
    \item Monitor every project's progress from design to implementation and solve issues in 95\% of the cases.
\end{itemize}

\vspace{1em}

% Job 2
\noindent
\textbf{Project Manager} \hfill \textit{Amazing Creations International} \\
\textit{03/2012 -- 12/2017} \hfill \textit{New York City, NY} \\
\begin{itemize}[left=0pt, itemsep=0.2em]
    \item Tracked website performance and recommended dynamic optimizations to stay within project budgets for 40 out of 45 projects.
    \item Generated in-depth reports on variances in project timelines, scopes, and budgets for all projects.
\end{itemize}

\vspace{1em}

% Job 3
\noindent
\textbf{Assistant Project Manager} \hfill \textit{Sunshine Big3 Enterprise} \\
\textit{02/2009 -- 01/2012} \hfill \textit{New York City, NY} \\
\begin{itemize}[left=0pt, itemsep=0.2em]
    \item Managed daily operations by overseeing cross-functional projects and maintaining customer satisfaction.
\end{itemize}

\vspace{1.5em}

% ------------------- Areas of Expertise -------------------
\section*{Areas of Expertise}
\noindent
\begin{minipage}[t]{0.48\textwidth}
    \begin{itemize}[left=0pt, itemsep=0.2em]
        \item Project Analysis
        \item Data Analysis
        \item Agile Methodology
        \item Quality Assurance
        \item Digital Operation Improvement
    \end{itemize}
\end{minipage}
\begin{minipage}[t]{0.48\textwidth}
    \begin{itemize}[left=0pt, itemsep=0.2em]
        \item JIRA, GitHub, CMS
        \item KPI Management
        \item Stakeholder Engagement
        \item Resource Optimization
        \item Workforce Management \& Coaching
    \end{itemize}
\end{minipage}

\vspace{1.5em}

% ------------------- Training and Certifications -------------------
\section*{Training and Certifications}
\begin{itemize}[left=0pt, itemsep=0.2em]
    \item PMP Certification Training Course (2019)
    \item Lean Six Sigma Black Belt Certified (2016)
    \item Strategic Workforce Planning Certified (2018)
    \item Situational Leadership II Certification (2014)
    \item Project Management Specialist Certified (2012)
\end{itemize}

\vspace{1.5em}

% ------------------- Education -------------------
\section*{Education}
\textbf{Master of Science in Project Management} \hfill \textit{New York University} \\
\textit{2010 -- 2012}

\vspace{1.5em}

% ------------------- Languages -------------------
\section*{Languages}
\begin{itemize}[left=0pt, itemsep=0.2em]
    \item English -- Native
    \item Norwegian -- Full Professional Proficiency
    \item Danish -- Full Professional Proficiency
    \item Swedish -- Full Professional Proficiency
\end{itemize}

\end{document}


### write me a python script to genereate resume
""").content)
# Out:
#   Cell In[6], line 1
#     print(llm.invoke("""
#                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 39-40: truncated \uXXXX escape

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://career55.sapsf.eu/career?career%5fns=job%5flisting&company=systemvent&navBarLevel=JOB%5fSEARCH&rcm%5fsite%5flocale=en%5fUS&career_job_req_id=2426&selected_lang=en_US&jobAlertController_jobAlertId=&jobAlertController_jobAlertName=&browserTimeZone=Asia/Karachi&_s.crb=wHll34wkuzpZZKEF%2fXqzqIs9Xwtyrb7LTkrtbufSolE%3d")
page_data = loader.load().pop().page_content
print(page_data)
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# * Senior Consultant Mobile Development (2426)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# JavaScript is turned off in your web browser. Turn it on to take full advantage of this site, then refresh the page.
#
# Loading...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to Main Content
#
#
#
#
#
#
#
#
#
#
# * Senior Consultant Mobile Development (2426)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ID: 2426 - Posted  - Country (1) - City (68) - 5-8 Years
#
#
#
#   Job Description Print Preview
#
#
#
#
#
#
#
#
#
# 	                  Apply
#
#
#
#
#
#
#
#
#
# 	                  Save Job
#
#
#
#
#
#
# 	                  Email Job to Friend
#
#
#
#
#
#
#                   Return to List
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
from langchain.prompts import PromptTemplate
promptScrape = PromptTemplate.from_template(
    """
        ### SCRAPED TEXT FROM WEBSITE:
        {page_data}
        ### INSTRUCTION:
        The scraped text is from the career's page of a website.
        Your job is to extract the job postings and return them in JSON format containing the 
        following keys: `role`, `experience`, `skills` and `description`.
        Only return the valid JSON.
        ### VALID JSON (NO PREAMBLE):    
        """
)
chainScrape = promptScrape | llm 
res = chainScrape.invoke(input={'page_data':page_data})
type(res.content)
# Out:
# str

# %%
res.content
# Out:
# '[\n  {\n    "role": "Senior Consultant Mobile Development",\n    "experience": "5-10 years",\n    "skills": [\n      "React Native",\n      "Redux",\n      "Redux Saga",\n      "RESTful APIs",\n      "Mobile performance optimization techniques",\n      "Native build tools (XCode, Gradle, Android Studio)",\n      "Automated testing and deployment processes",\n      "Flutter",\n      "Dart",\n      "TypeScript",\n      "Expo",\n      "CI/CD practices"\n    ],\n    "description": "We are looking for an experienced React Native Developer to join our dynamic team. The ideal candidate should have 5-10 years of experience in mobile app development with a strong proficiency in React Native. Experience with Flutter is a plus."\n  }\n]'

# %%
from langchain_core.output_parsers import JsonOutputParser
jsonparser = JsonOutputParser()
jsonRes = jsonparser.parse(res.content)
print(len(jsonRes))

# dict(jsonRes)
# print(jsonRes)
# Out:
# 1

# %%
import pandas as pd

df = pd.read_csv("my_portfolio.csv")
df
# Out:
#                                Techstack  \
# 0                React, Node.js, MongoDB
# 1               Angular,.NET, SQL Server
# 2      Vue.js, Ruby on Rails, PostgreSQL
# 3                  Python, Django, MySQL
# 4              Java, Spring Boot, Oracle
# 5             Flutter, Firebase, GraphQL
# 6                  WordPress, PHP, MySQL
# 7                    Magento, PHP, MySQL
# 8         React Native, Node.js, MongoDB
# 9                  iOS, Swift, Core Data
# 10       Android, Java, Room Persistence
# 11             Kotlin, Android, Firebase
# 12       Android TV, Kotlin, Android NDK
# 13                     iOS, Swift, ARKit
# 14        Cross-platform, Xamarin, Azure
# 15          Backend, Kotlin, Spring Boot
# 16         Frontend, TypeScript, Angular
# 17    Full-stack, JavaScript, Express.js
# 18  Machine Learning, Python, TensorFlow
# 19               DevOps, Jenkins, Docker
#
#                                                 Links
# ...

# %%
import chromadb
import uuid

client = chromadb.PersistentClient("vectordb")
collection = client.get_or_create_collection(name="portfolio")

if not collection.count():
 for _, row in df.iterrows():
        collection.add(documents=row["Techstack"],
                       metadatas={"links": row["Links"]},
                       ids=[str(uuid.uuid4())])
# Out:
# C:\Users\Hamza\.cache\chroma\onnx_models\all-MiniLM-L6-v2\onnx.tar.gz: 100%|██████| 79.3M/79.3M [02:15<00:00, 616kiB/s]

# %%
job = jsonRes[0]
job['skills']
# Out:
# ['Python',
#  'APIs (Application Programming Interfaces)',
#  'Web Development Frameworks',
#  'Javascript',
#  'HTML',
#  'XML',
#  'Model View Controller architecture',
#  'Numpy',
#  'Pandas',
#  'Database Knowledge',
#  'DevOps Practices']

# %%
links = collection.query(query_texts=job['skills'], n_results=2).get('metadatas', [])
links
# Out:
# [[{'links': 'https://example.com/ml-python-portfolio'},
#   {'links': 'https://example.com/python-portfolio'}],
#  [{'links': 'https://example.com/ios-ar-portfolio'},
#   {'links': 'https://example.com/magento-portfolio'}],
#  [{'links': 'https://example.com/wordpress-portfolio'},
#   {'links': 'https://example.com/magento-portfolio'}],
#  [{'links': 'https://example.com/full-stack-js-portfolio'},
#   {'links': 'https://example.com/typescript-frontend-portfolio'}],
#  [{'links': 'https://example.com/wordpress-portfolio'},
#   {'links': 'https://example.com/magento-portfolio'}],
#  [{'links': 'https://example.com/magento-portfolio'},
#   {'links': 'https://example.com/wordpress-portfolio'}],
#  [{'links': 'https://example.com/ios-portfolio'},
#   {'links': 'https://example.com/ios-ar-portfolio'}],
#  [{'links': 'https://example.com/ml-python-portfolio'},
#   {'links': 'https://example.com/python-portfolio'}],
#  [{'links': 'https://example.com/ml-python-portfolio'},
# ...

# %%
prompt_email = PromptTemplate.from_template(
        """
        ### JOB DESCRIPTION:
        {job_description}
        
        ### INSTRUCTION:
        You are Hamza Ali, AI\ML Engineer at Techyaim. Techyaim is an AI & Software Consulting company dedicated to facilitating
        the seamless integration of business processes through automated tools. 
        Over our experience, we have empowered numerous enterprises with tailored solutions, fostering scalability, 
        process optimization, cost reduction, and heightened overall efficiency. 
        Your job is to write a cold email to the client regarding the job mentioned above describing the capability of Techyaim 
        in fulfilling their needs.
        Also add the most relevant ones from the following links to showcase Techyaim's portfolio: {link_list}
        Remember you are Hamza, AI\ML Engineer at Techyaim. 
        Do not provide a preamble.
        ### EMAIL (NO PREAMBLE):
        
        """
        )

chain_email = prompt_email | llm
res = chain_email.invoke({"job_description": str(job), "link_list": links})
print(res.content)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\M'
# <>:2: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\Hamza\AppData\Local\Temp\ipykernel_5368\2652691905.py:2: SyntaxWarning: invalid escape sequence '\M'
#   """
# Subject: Expert Python Development Services for Your Business Needs
#
# Dear Hiring Manager,
#
# I came across your job posting for a Python Developer Interns - Lead to Permanent Job, and I'm excited to introduce you to Techyaim, an AI & Software Consulting company that can help you find the perfect candidate or even take care of the development needs in-house.
#
# At Techyaim, we have a team of experienced Python developers who are well-versed in APIs, Web Development Frameworks, Javascript, HTML, XML, Model View Controller architecture, Numpy, Pandas, and Database Knowledge. Our team is also familiar with DevOps Practices, ensuring that our solutions are efficient, scalable, and reliable.
#
# ...
